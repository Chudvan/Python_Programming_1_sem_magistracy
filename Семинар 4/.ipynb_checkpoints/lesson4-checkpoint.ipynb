# %%
import requests
import pandas as pd

# %%
items = requests.get('https://api.hh.ru/vacancies?text=бухгалтер&per_page=100&page=9').json()['items']
items
# Out:
# [{'id': '48657968',
#   'premium': False,
#   'name': 'Главный бухгалтер в единственном лице',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': {'from': 90000, 'to': 110000, 'currency': 'RUR', 'gross': False},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': None,
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2021-10-14T17:11:28+0300',
#   'created_at': '2021-10-14T17:11:28+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=48657968',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/48657968?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/48657968',
#   'relations': [],
#   'employer': {'id': '11133',
#    'name': 'Jetcom',
#    'url': 'https://api.hh.ru/employers/11133',
#    'alternate_url': 'https://hh.ru/employer/11133',
#    'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/516428.png',
#     '90': 'https://hhcdn.ru/employer-logo/2507288.png',
#     '240': 'https://hhcdn.ru/employer-logo/2507289.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=11133',
#    'trusted': True},
#   'snippet': {'requirement': 'Опыт работы с обособленными подразделениями. 1С Управление торговлей, 1С <highlighttext>Бухгалтерия</highlighttext> 8.3, ЗУП 8.3, Контур экстерн (эл.отчетность...',
#    'responsibility': 'Ведение бухгалтерского учета в единственном лице. Контроль выгруженных из управленческой базы (вводить не надо): первичных док-ов, реализации и поступления...'},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '48722257',
#   'premium': False,
#   'name': 'Бухгалтер (производство)',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '2',
#    'name': 'Санкт-Петербург',
#    'url': 'https://api.hh.ru/areas/2'},
#   'salary': {'from': 70000, 'to': None, 'currency': 'RUR', 'gross': False},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Санкт-Петербург',
#    'street': 'Лисичанская улица',
#    'building': '5',
#    'description': None,
#    'lat': 59.985962,
#    'lng': 30.316874,
#    'raw': 'Санкт-Петербург, Лисичанская улица, 5',
#    'metro': None,
#    'metro_stations': [],
#    'id': '3702149'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2021-10-13T11:35:59+0300',
#   'created_at': '2021-10-13T11:35:59+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=48722257',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/48722257?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/48722257',
#   'relations': [],
#   'employer': {'id': '2187035',
#    'name': 'Nanosmoke',
#    'url': 'https://api.hh.ru/employers/2187035',
#    'alternate_url': 'https://hh.ru/employer/2187035',
#    'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/663864.jpg',
#     '240': 'https://hhcdn.ru/employer-logo/3096589.jpeg',
#     '90': 'https://hhcdn.ru/employer-logo/3096588.jpeg'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2187035',
#    'trusted': True},
#   'snippet': {'requirement': '...и 1С <highlighttext>Бухгалтерия</highlighttext>, понимание правил переноса данных. Требования: - Высшее образование. - Опыт работы в 1С <highlighttext>Бухгалтерия</highlighttext> и 1С...',
#    'responsibility': 'Ведение ИП (1 ИП, УСН доходы минус расходы) + ООО (ОСНО), малый бизнес в полном объёме. - Учет расчетов с поставщиками...'},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '42774239',
#   'premium': False,
#   'name': 'Бухгалтер ТМЦ (склад)',
#   'department': None,
#   'has_test': True,
#   'response_letter_required': False,
#   'area': {'id': '4',
#    'name': 'Новосибирск',
#    'url': 'https://api.hh.ru/areas/4'},
#   'salary': {'from': 65000, 'to': None, 'currency': 'RUR', 'gross': False},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': None,
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2021-10-15T10:24:24+0300',
#   'created_at': '2021-10-15T10:24:24+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=42774239',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/42774239?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/42774239',
#   'relations': [],
#   'employer': {'id': '681883',
#    'name': 'Велесстрой',
#    'url': 'https://api.hh.ru/employers/681883',
#    'alternate_url': 'https://hh.ru/employer/681883',
#    'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/526364.png',
#     '240': 'https://hhcdn.ru/employer-logo/2546934.png',
#     '90': 'https://hhcdn.ru/employer-logo/2546933.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=681883',
#    'trusted': True},
#   'snippet': {'requirement': 'Опыт работы учетчиком, <highlighttext>бухгалтером</highlighttext> не менее 2-х лет. Знание программы 1С, Excel. Опыт работы в строительстве.',
#    'responsibility': 'Ведение учета ТМЦ на складе (прием / выбытие / перемещение), проведение операций в программе 1С. Учет давальческого материала (стройматериалы, оборудование). '},
#   'contacts': None,
#   'schedule': {'id': 'flyInFlyOut', 'name': 'Вахтовый метод'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '48758166',
#   'premium': False,
#   'name': 'Делопроизводитель (бухгалтерия)',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '2',
#    'name': 'Санкт-Петербург',
#    'url': 'https://api.hh.ru/areas/2'},
#   'salary': {'from': 40000, 'to': None, 'currency': 'RUR', 'gross': False},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Санкт-Петербург',
#    'street': 'Московский проспект',
#    'building': '158Б',
#    'description': None,
#    'lat': 59.880013,
#    'lng': 30.322812,
#    'raw': 'Санкт-Петербург, Московский проспект, 158Б',
#    'metro': {'station_name': 'Электросила',
#     'line_name': 'Московско-Петроградская',
#     'station_id': '15.222',
#     'line_id': '15',
#     'lat': 59.879189,
#     'lng': 30.318659},
#    'metro_stations': [{'station_name': 'Электросила',
#      'line_name': 'Московско-Петроградская',
#      'station_id': '15.222',
#      'line_id': '15',
#      'lat': 59.879189,
#      'lng': 30.318659}],
#    'id': '798836'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2021-10-15T14:08:50+0300',
#   'created_at': '2021-10-15T14:08:50+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=48758166',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/48758166?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/48758166',
#   'relations': [],
#   'employer': {'id': '544626',
#    'name': 'NBCom Group',
#    'url': 'https://api.hh.ru/employers/544626',
#    'alternate_url': 'https://hh.ru/employer/544626',
#    'logo_urls': {'90': 'https://hhcdn.ru/employer-logo/3634891.png',
#     '240': 'https://hhcdn.ru/employer-logo/3634892.png',
#     'original': 'https://hhcdn.ru/employer-logo-original/798501.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=544626',
#    'trusted': True},
#   'snippet': {'requirement': 'Опыт работы на аналогичной должности от года желателен. Базовые знания 1С <highlighttext>Бухгалтерия</highlighttext> и Торговля. Аккуратности и внимательности в ведении...',
#    'responsibility': 'Разбирать и проверять первичные бухгалтерские документы, контролировать их наличие. Проверять путевые листы. Находить и сканировать документы по запросам внешних и...'},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '47709417',
#   'premium': False,
#   'name': 'Бухгалтер',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '99', 'name': 'Уфа', 'url': 'https://api.hh.ru/areas/99'},
#   'salary': {'from': 40000, 'to': 40000, 'currency': 'RUR', 'gross': False},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Уфа',
#    'street': 'улица Чернышевского',
#    'building': '75',
#    'description': None,
#    'lat': 54.729444,
#    'lng': 55.94651,
#    'raw': 'Уфа, улица Чернышевского, 75',
#    'metro': None,
#    'metro_stations': [],
#    'id': '6572456'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2021-10-14T10:05:48+0300',
#   'created_at': '2021-10-14T10:05:48+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=47709417',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/47709417?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/47709417',
#   'relations': [],
#   'employer': {'id': '3735399',
#    'name': 'Управляющая Компания РЕМ-Сервис',
#    'url': 'https://api.hh.ru/employers/3735399',
#    'alternate_url': 'https://hh.ru/employer/3735399',
#    'logo_urls': None,
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3735399',
#    'trusted': True},
#   'snippet': {'requirement': 'Знание бухгалтерского, налогового и управленческого учета. Знание УСНО. Знание программы "1С: <highlighttext>Бухгалтерия</highlighttext> 8.3", "1С: ЗУП 8.3". ',
#    'responsibility': '...с заказчиками и поставщиками. Ведение управленческого учета в Еxcel. Изучение норм законодательства в СПС Консультант плюс. Выполнение поручений главного <highlighttext>бухгалтера</highlighttext>.'},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '48772583',
#   'premium': False,
#   'name': 'Бухгалтер на первичную документацию',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '32',
#    'name': 'Иваново (Ивановская область)',
#    'url': 'https://api.hh.ru/areas/32'},
#   'salary': {'from': 25000, 'to': 40000, 'currency': 'RUR', 'gross': False},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Иваново',
#    'street': 'Типографская улица',
#    'building': '6',
#    'description': None,
#    'lat': 56.98632,
#    'lng': 40.979706,
#    'raw': 'Иваново, Типографская улица, 6',
#    'metro': None,
#    'metro_stations': [],
#    'id': '3952554'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2021-10-12T19:19:22+0300',
#   'created_at': '2021-10-12T19:19:22+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=48772583',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/48772583?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/48772583',
#   'relations': [],
#   'employer': {'id': '2802078',
#    'name': 'Армос ЦентрОПТ',
#    'url': 'https://api.hh.ru/employers/2802078',
#    'alternate_url': 'https://hh.ru/employer/2802078',
#    'logo_urls': None,
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2802078',
#    'trusted': True},
#   'snippet': {'requirement': 'Опыт работы от 1 года в аналогичной должности. Высшее образование.',
#    'responsibility': 'Контроль, сбор первичной документации от поставщиков. Контроль, сбор первичной документации от контрагентов. Сбор документации для банков/партнёров. Поддержание актуальной сверки...'},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '48855147',
#   'premium': False,
#   'name': 'Бухгалтер на первичную документацию',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '2',
#    'name': 'Санкт-Петербург',
#    'url': 'https://api.hh.ru/areas/2'},
#   'salary': {'from': 40000, 'to': 45000, 'currency': 'RUR', 'gross': True},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Санкт-Петербург',
#    'street': 'Вербная улица',
#    'building': '27',
#    'description': None,
#    'lat': 60.023506,
#    'lng': 30.298611,
#    'raw': 'Санкт-Петербург, Вербная улица, 27',
#    'metro': {'station_name': 'Комендантский проспект',
#     'line_name': 'Фрунзенско-Приморская',
#     'station_id': '18.245',
#     'line_id': '18',
#     'lat': 60.008591,
#     'lng': 30.258663},
#    'metro_stations': [{'station_name': 'Комендантский проспект',
#      'line_name': 'Фрунзенско-Приморская',
#      'station_id': '18.245',
#      'line_id': '18',
#      'lat': 60.008591,
#      'lng': 30.258663},
#     {'station_name': 'Озерки',
#      'line_name': 'Московско-Петроградская',
#      'station_id': '15.211',
#      'line_id': '15',
#      'lat': 60.037098,
#      'lng': 30.321495},
#     {'station_name': 'Пионерская',
#      'line_name': 'Московско-Петроградская',
#      'station_id': '15.213',
#      'line_id': '15',
#      'lat': 60.002487,
#      'lng': 30.296759},
#     {'station_name': 'Удельная',
#      'line_name': 'Московско-Петроградская',
#      'station_id': '15.212',
#      'line_id': '15',
#      'lat': 60.016697,
#      'lng': 30.315607}],
#    'id': '665136'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2021-10-14T18:24:54+0300',
#   'created_at': '2021-10-14T18:24:54+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=48855147',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/48855147?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/48855147',
#   'relations': [],
#   'employer': {'id': '1060263',
#    'name': 'Ленинградский, ТД',
#    'url': 'https://api.hh.ru/employers/1060263',
#    'alternate_url': 'https://hh.ru/employer/1060263',
#    'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/816452.jpg',
#     '240': 'https://hhcdn.ru/employer-logo/3706696.jpeg',
#     '90': 'https://hhcdn.ru/employer-logo/3706695.jpeg'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=1060263',
#    'trusted': True},
#   'snippet': {'requirement': 'Опыт работы в Общепите <highlighttext>бухгалтером</highlighttext> -калькулятором или <highlighttext>бухгалтером</highlighttext> от 2-х лет. Умение работать с большим объемом информации. Знание бух. ',
#    'responsibility': 'Внесение отчетов (результаты инвентаризаций, товарные отчеты) в учетную программу (1С 8.3). Занесение данных по приходу товара, создание реализаций...'},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '48635378',
#   'premium': False,
#   'name': 'Старший бухгалтер',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': {'from': 71600, 'to': 71600, 'currency': 'RUR', 'gross': False},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Москва',
#    'street': 'Новодмитровская улица',
#    'building': '2к1',
#    'description': None,
#    'lat': 55.804936,
#    'lng': 37.589922,
#    'raw': 'Москва, Новодмитровская улица, 2к1',
#    'metro': {'station_name': 'Дмитровская',
#     'line_name': 'Серпуховско-Тимирязевская',
#     'station_id': '9.35',
#     'line_id': '9',
#     'lat': 55.808056,
#     'lng': 37.581734},
#    'metro_stations': [{'station_name': 'Дмитровская',
#      'line_name': 'Серпуховско-Тимирязевская',
#      'station_id': '9.35',
#      'line_id': '9',
#      'lat': 55.808056,
#      'lng': 37.581734}],
#    'id': '597793'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2021-10-14T09:52:29+0300',
#   'created_at': '2021-10-14T09:52:29+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=48635378',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/48635378?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/48635378',
#   'relations': [],
#   'employer': {'id': '56526',
#    'name': 'ТЕЛС-РУС',
#    'url': 'https://api.hh.ru/employers/56526',
#    'alternate_url': 'https://hh.ru/employer/56526',
#    'logo_urls': {'90': 'https://hhcdn.ru/employer-logo/322183.jpeg',
#     '240': 'https://hhcdn.ru/employer-logo/395040.jpeg',
#     'original': 'https://hhcdn.ru/employer-logo-original/219484.jpg'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=56526',
#    'trusted': True},
#   'snippet': {'requirement': 'Профильное образование : экономика / бухгалтерский учет и аудит. Опыт работы в долж\xadности <highlighttext>бухгалтера</highlighttext> по банковским операциям от 2 лет. ',
#    'responsibility': 'Разнесение банковских выписок в учетной системе 1С <highlighttext>Бухгалтерия</highlighttext> и в управленческой базе. Осуществление контроля за корректностью и полнотой входящих...'},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '48544711',
#   'premium': False,
#   'name': 'Ведущий (старший бухгалтер)',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': {'from': 70000, 'to': 80000, 'currency': 'RUR', 'gross': False},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': None,
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2021-10-14T17:31:02+0300',
#   'created_at': '2021-10-14T17:31:02+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=48544711',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/48544711?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/48544711',
#   'relations': [],
#   'employer': {'id': '2954242',
#    'name': 'Такс Логос Консалтинг',
#    'url': 'https://api.hh.ru/employers/2954242',
#    'alternate_url': 'https://hh.ru/employer/2954242',
#    'logo_urls': None,
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2954242',
#    'trusted': True},
#   'snippet': {'requirement': 'Опыт работы <highlighttext>бухгалтером</highlighttext>, от 5-ти лет. Уверенное знание программы 1С 8.2 и 8.3 <highlighttext>бухгалтерия</highlighttext>, ЗУП. ',
#    'responsibility': 'Подготовка и сдача отчетности в ИФНС и Фонды (под контролем главного <highlighttext>бухгалтера</highlighttext>). Взаимодействие с ИФНС и государственными фондами (сверка расчетов...'},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '48800327',
#   'premium': False,
#   'name': 'Бухгалтер (участок реализация)',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '2',
#    'name': 'Санкт-Петербург',
#    'url': 'https://api.hh.ru/areas/2'},
#   'salary': {'from': 50000, 'to': None, 'currency': 'RUR', 'gross': False},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Санкт-Петербург',
#    'street': None,
#    'building': None,
#    'description': None,
#    'lat': 59.879688,
#    'lng': 30.261921,
#    'raw': 'Санкт-Петербург',
#    'metro': {'station_name': 'Кировский завод',
#     'line_name': 'Кировско-Выборгская',
#     'station_id': '14.205',
#     'line_id': '14',
#     'lat': 59.879688,
#     'lng': 30.261921},
#    'metro_stations': [{'station_name': 'Кировский завод',
#      'line_name': 'Кировско-Выборгская',
#      'station_id': '14.205',
#      'line_id': '14',
#      'lat': 59.879688,
#      'lng': 30.261921}],
#    'id': '458600'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2021-10-13T13:31:30+0300',
#   'created_at': '2021-10-13T13:31:30+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=48800327',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/48800327?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/48800327',
#   'relations': [],
#   'employer': {'id': '232489',
#    'name': 'АРЕС',
#    'url': 'https://api.hh.ru/employers/232489',
#    'alternate_url': 'https://hh.ru/employer/232489',
#    'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/992361.jpeg',
#     '90': 'https://hhcdn.ru/employer-logo/992360.jpeg',
#     'original': 'https://hhcdn.ru/employer-logo-original/186197.jpg'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=232489',
#    'trusted': True},
#   'snippet': {'requirement': 'Опыт работы на участке. Работа в транспортно-логистических компаниях - преимущество. Навык работы в программах 1С 8.3, outlook, Excel...',
#    'responsibility': 'Работа на участке реализации экспорт: - выставление счетов/актов/сч-ф/ invoices. - подготовка и сбор всех документов для подтверждение НДС 0...'},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '48872712',
#   'premium': False,
#   'name': 'Бухгалтер на участок',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '22',
#    'name': 'Владивосток',
#    'url': 'https://api.hh.ru/areas/22'},
#   'salary': {'from': 50000, 'to': None, 'currency': 'RUR', 'gross': False},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Владивосток',
#    'street': 'улица Лазо',
#    'building': None,
#    'description': None,
#    'lat': 43.115404,
#    'lng': 131.894971,
#    'raw': 'Владивосток, улица Лазо',
#    'metro': None,
#    'metro_stations': [],
#    'id': '758139'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2021-10-15T12:35:59+0300',
#   'created_at': '2021-10-15T12:35:59+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=48872712',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/48872712?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/48872712',
#   'relations': [],
#   'employer': {'id': '2221919',
#    'name': 'СанМарин Пасифик',
#    'url': 'https://api.hh.ru/employers/2221919',
#    'alternate_url': 'https://hh.ru/employer/2221919',
#    'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/817338.jpg',
#     '240': 'https://hhcdn.ru/employer-logo/3710240.jpeg',
#     '90': 'https://hhcdn.ru/employer-logo/3710239.jpeg'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2221919',
#    'trusted': True},
#   'snippet': {'requirement': 'Знание 1С, офисных программ.',
#    'responsibility': '...заработной платы, страховых взносов, налогов. 2. заказ расходных материалов для офиса, отправка/прием почтовой корреспонденции. 3. Выполнение поручений главного <highlighttext>бухгалтера</highlighttext>.'},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '48381566',
#   'premium': False,
#   'name': 'Бухгалтер',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': {'from': 65000, 'to': 65000, 'currency': 'RUR', 'gross': False},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Москва',
#    'street': 'Стремянный переулок',
#    'building': '11',
#    'description': None,
#    'lat': 55.727633,
#    'lng': 37.633374,
#    'raw': 'Москва, Стремянный переулок, 11',
#    'metro': {'station_name': 'Павелецкая',
#     'line_name': 'Замоскворецкая',
#     'station_id': '2.101',
#     'line_id': '2',
#     'lat': 55.729741,
#     'lng': 37.638693},
#    'metro_stations': [{'station_name': 'Павелецкая',
#      'line_name': 'Замоскворецкая',
#      'station_id': '2.101',
#      'line_id': '2',
#      'lat': 55.729741,
#      'lng': 37.638693},
#     {'station_name': 'Павелецкая',
#      'line_name': 'Кольцевая',
#      'station_id': '5.102',
#      'line_id': '5',
#      'lat': 55.731414,
#      'lng': 37.636294},
#     {'station_name': 'Серпуховская',
#      'line_name': 'Серпуховско-Тимирязевская',
#      'station_id': '9.37',
#      'line_id': '9',
#      'lat': 55.726548,
#      'lng': 37.624792}],
#    'id': '55252'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2021-10-14T18:01:57+0300',
#   'created_at': '2021-10-14T18:01:57+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=48381566',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/48381566?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/48381566',
#   'relations': [],
#   'employer': {'id': '28330',
#    'name': 'Управляющая Компания Отель',
#    'url': 'https://api.hh.ru/employers/28330',
#    'alternate_url': 'https://hh.ru/employer/28330',
#    'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/760888.jpg',
#     '90': 'https://hhcdn.ru/employer-logo/3484509.jpeg',
#     '240': 'https://hhcdn.ru/employer-logo/3484510.jpeg'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=28330',
#    'trusted': True},
#   'snippet': {'requirement': 'Умение работать в MS EXCEL, Word, 1С <highlighttext>Бухгалтерия</highlighttext> 8.3, 1С ЗУП 8.3. - Клиент-банк. - ',
#    'responsibility': '...с контрагентами по сч. 62 и сч. 60, совместно с главным <highlighttext>бухгалтером</highlighttext> и отделом продаж. - Выполнение дополнительных поручений главного <highlighttext>бухгалтера</highlighttext>.'},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '48053645',
#   'premium': False,
#   'name': 'Главный бухгалтер в транспортную компанию',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '88', 'name': 'Казань', 'url': 'https://api.hh.ru/areas/88'},
#   'salary': {'from': 70000, 'to': None, 'currency': 'RUR', 'gross': False},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Казань',
#    'street': 'улица Парижской Коммуны',
#    'building': '26',
#    'description': None,
#    'lat': 55.780831,
#    'lng': 49.110591,
#    'raw': 'Казань, улица Парижской Коммуны, 26',
#    'metro': {'station_name': 'Площадь Тукая',
#     'line_name': 'Центральная',
#     'station_id': '49.273',
#     'line_id': '49',
#     'lat': 55.787163,
#     'lng': 49.122126},
#    'metro_stations': [{'station_name': 'Площадь Тукая',
#      'line_name': 'Центральная',
#      'station_id': '49.273',
#      'line_id': '49',
#      'lat': 55.787163,
#      'lng': 49.122126}],
#    'id': '780289'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2021-10-15T12:32:57+0300',
#   'created_at': '2021-10-15T12:32:57+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=48053645',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/48053645?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/48053645',
#   'relations': [],
#   'employer': {'id': '2746953',
#    'name': 'УДАЧА КАЗАНЬ',
#    'url': 'https://api.hh.ru/employers/2746953',
#    'alternate_url': 'https://hh.ru/employer/2746953',
#    'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3815564.jpeg',
#     '90': 'https://hhcdn.ru/employer-logo/3815563.jpeg',
#     'original': 'https://hhcdn.ru/employer-logo-original/843672.jpeg'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2746953',
#    'trusted': True},
#   'snippet': {'requirement': 'Высшее финансово-экономическое образование. Опыт работы в должности Главного <highlighttext>бухгалтера</highlighttext> от 5 лет. Опытный пользователь MS Office, программ ЭДО.',
#    'responsibility': 'Руководство <highlighttext>бухгалтерией</highlighttext>. Организация ведения бухгалтерского и налогового учета нескольних юридических лиц. Взаимодействие с налоговыми органами и подготовка ответов на требования...'},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '48808919',
#   'premium': False,
#   'name': 'Ведущий бухгалтер участка бухгалтерского и налогового учета',
#   'department': {'id': 'LCR-3344-uprk', 'name': 'ООО «ЛСР»'},
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '2',
#    'name': 'Санкт-Петербург',
#    'url': 'https://api.hh.ru/areas/2'},
#   'salary': {'from': None, 'to': 90000, 'currency': 'RUR', 'gross': True},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': None,
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2021-10-13T16:08:26+0300',
#   'created_at': '2021-10-13T16:08:26+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=48808919',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/48808919?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/48808919',
#   'relations': [],
#   'employer': {'id': '3344',
#    'name': 'Группа ЛСР',
#    'url': 'https://api.hh.ru/employers/3344',
#    'alternate_url': 'https://hh.ru/employer/3344',
#    'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/1513451.jpeg',
#     '90': 'https://hhcdn.ru/employer-logo/1513450.jpeg',
#     'original': 'https://hhcdn.ru/employer-logo-original/267730.jpg'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3344',
#    'trusted': True},
#   'snippet': {'requirement': 'Высшее образование. Опыт работы в должности <highlighttext>бухгалтера</highlighttext> не менее 3-х лет. Знание основ российских стандартов бухгалтерского учета, знание основ...',
#    'responsibility': 'Проверка корректности отражения операций в 1С:БП по вверенным юридическим лицам, в части налогового учета. Расчет и начисление налогов...'},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '48299703',
#   'premium': False,
#   'name': 'Бухгалтер',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '2',
#    'name': 'Санкт-Петербург',
#    'url': 'https://api.hh.ru/areas/2'},
#   'salary': {'from': 60000, 'to': None, 'currency': 'RUR', 'gross': False},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Санкт-Петербург',
#    'street': 'улица Латышских Стрелков',
#    'building': '19Д',
#    'description': None,
#    'lat': 59.931783,
#    'lng': 30.450651,
#    'raw': 'Санкт-Петербург, улица Латышских Стрелков, 19Д',
#    'metro': None,
#    'metro_stations': [],
#    'id': '4171435'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2021-10-15T16:01:17+0300',
#   'created_at': '2021-10-15T16:01:17+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=48299703',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/48299703?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/48299703',
#   'relations': [],
#   'employer': {'id': '4833910',
#    'name': 'Новатекс',
#    'url': 'https://api.hh.ru/employers/4833910',
#    'alternate_url': 'https://hh.ru/employer/4833910',
#    'logo_urls': None,
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=4833910',
#    'trusted': True},
#   'snippet': {'requirement': 'Высшее профессиональное образование. ОБЯЗАТЕЛЬНО ЗНАТЬ ПРОИЗВОДСТВО. Опыт работы зам.главного <highlighttext>бухгалтера</highlighttext>/ главным <highlighttext>бухгалтером</highlighttext>. Знание всех участков бухгалтерского учета. Знание российского законодательства...',
#    'responsibility': 'Ведение ООО (ОСНО) в полном объеме. Начисление оплаты труда, пособий по нетрудоспособности, отпускных и пр.; исчисление и уплата налогов и...'},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '48849088',
#   'premium': False,
#   'name': 'Главный бухгалтер в единственном лице',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': {'from': 100000, 'to': 100000, 'currency': 'RUR', 'gross': False},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': None,
#    'street': None,
#    'building': None,
#    'description': None,
#    'lat': None,
#    'lng': None,
#    'raw': None,
#    'metro': {'station_name': 'Кунцевская',
#     'line_name': 'Арбатско-Покровская',
#     'station_id': '3.69',
#     'line_id': '3',
#     'lat': 55.730673,
#     'lng': 37.446522},
#    'metro_stations': [{'station_name': 'Кунцевская',
#      'line_name': 'Арбатско-Покровская',
#      'station_id': '3.69',
#      'line_id': '3',
#      'lat': 55.730673,
#      'lng': 37.446522},
#     {'station_name': 'Кунцевская',
#      'line_name': 'Филевская',
#      'station_id': '4.471',
#      'line_id': '4',
#      'lat': 55.730815,
#      'lng': 37.446754},
#     {'station_name': 'Кунцевская',
#      'line_name': 'МЦД - 1',
#      'station_id': '131.704',
#      'line_id': '131',
#      'lat': 55.730554,
#      'lng': 37.445591}],
#    'id': '4859159'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2021-10-14T15:47:55+0300',
#   'created_at': '2021-10-14T15:47:55+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=48849088',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/48849088?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/48849088',
#   'relations': [],
#   'employer': {'id': '4684720',
#    'name': 'Job Offer',
#    'url': 'https://api.hh.ru/employers/4684720',
#    'alternate_url': 'https://hh.ru/employer/4684720',
#    'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3439082.jpeg',
#     '90': 'https://hhcdn.ru/employer-logo/3439081.jpeg',
#     'original': 'https://hhcdn.ru/employer-logo-original/749530.jpg'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=4684720',
#    'trusted': True},
#   'snippet': {'requirement': '...С <highlighttext>Бухгалтерия</highlighttext> 8.3, 1С ЗУП, MS Exсel , Word, Outlook, справочных информационных систем. Опыт работы на позиции Главного <highlighttext>бухгалтера</highlighttext>...',
#    'responsibility': 'Ведение бухгалтерского и налогового учета. Формирование и сдача бухгалтерской и налоговой отчетности. ОСНО, УСН. Обеспечение рациональной организации бухгалтерского учета и...'},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '48027060',
#   'premium': False,
#   'name': 'Бухгалтер',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': {'from': 60000, 'to': 80000, 'currency': 'RUR', 'gross': False},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Москва',
#    'street': 'Малая Бронная улица',
#    'building': '31/13',
#    'description': None,
#    'lat': 55.765149,
#    'lng': 37.59144,
#    'raw': 'Москва, Малая Бронная улица, 31/13',
#    'metro': {'station_name': 'Маяковская',
#     'line_name': 'Замоскворецкая',
#     'station_id': '2.80',
#     'line_id': '2',
#     'lat': 55.769808,
#     'lng': 37.596192},
#    'metro_stations': [{'station_name': 'Маяковская',
#      'line_name': 'Замоскворецкая',
#      'station_id': '2.80',
#      'line_id': '2',
#      'lat': 55.769808,
#      'lng': 37.596192}],
#    'id': '5857303'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2021-10-13T18:51:25+0300',
#   'created_at': '2021-10-13T18:51:25+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=48027060',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/48027060?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/48027060',
#   'relations': [],
#   'employer': {'id': '5396192',
#    'name': 'Гамма Консалтинг',
#    'url': 'https://api.hh.ru/employers/5396192',
#    'alternate_url': 'https://hh.ru/employer/5396192',
#    'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3859968.png',
#     '90': 'https://hhcdn.ru/employer-logo/3859967.png',
#     'original': 'https://hhcdn.ru/employer-logo-original/854773.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=5396192',
#    'trusted': True},
#   'snippet': {'requirement': 'Опыт работы не менее 3-х лет. Опыт пользования 1С. Ответственность, умение работать в команде, высокая работоспособность, доброжелательность.',
#    'responsibility': 'Ведение расчетов с поставщиками и покупателями. Формирование реестров платежей. Валютные операции. Ведение кассовых операций. Работа в 1С <highlighttext>Бухгалтерии</highlighttext>. '},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '48356960',
#   'premium': False,
#   'name': 'Бухгалтер/помощник руководителя',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '2078',
#    'name': 'Чехов',
#    'url': 'https://api.hh.ru/areas/2078'},
#   'salary': {'from': 60000, 'to': 70000, 'currency': 'RUR', 'gross': False},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Чехов',
#    'street': 'улица Чехова',
#    'building': '20Бк35',
#    'description': None,
#    'lat': 55.143085,
#    'lng': 37.472441,
#    'raw': 'Чехов, улица Чехова, 20Бк35',
#    'metro': None,
#    'metro_stations': [],
#    'id': '5793430'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2021-10-14T10:07:39+0300',
#   'created_at': '2021-10-14T10:07:39+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=48356960',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/48356960?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/48356960',
#   'relations': [],
#   'employer': {'id': '2726348',
#    'name': 'Ваяр',
#    'url': 'https://api.hh.ru/employers/2726348',
#    'alternate_url': 'https://hh.ru/employer/2726348',
#    'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/2865089.jpeg',
#     '90': 'https://hhcdn.ru/employer-logo/2865088.jpeg',
#     'original': 'https://hhcdn.ru/employer-logo-original/605984.jpg'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2726348',
#    'trusted': True},
#   'snippet': {'requirement': 'Высшее бухгалтерское, финансово-экономическое образование. Опыт работы <highlighttext>бухгалтером</highlighttext> от 3-х лет. Уверенное владение ПК. Ответственность.',
#    'responsibility': 'Ведение бухгалтерского и налогового учета в полном объёме. Ведение кадрового учёта. Подготовка и прием первичной документации. Взаимодействие с банками, осуществление...'},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '48339850',
#   'premium': False,
#   'name': 'Бухгалтер/Помощник руководителя',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '76',
#    'name': 'Ростов-на-Дону',
#    'url': 'https://api.hh.ru/areas/76'},
#   'salary': {'from': 40000, 'to': 50000, 'currency': 'RUR', 'gross': False},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Ростов-на-Дону',
#    'street': 'проспект Михаила Нагибина',
#    'building': '14Г',
#    'description': None,
#    'lat': 47.247378,
#    'lng': 39.714833,
#    'raw': 'Ростов-на-Дону, проспект Михаила Нагибина, 14Г',
#    'metro': None,
#    'metro_stations': [],
#    'id': '6585568'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2021-10-13T16:02:09+0300',
#   'created_at': '2021-10-13T16:02:09+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=48339850',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/48339850?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/48339850',
#   'relations': [],
#   'employer': {'id': '5756305',
#    'name': 'SK HOUSE',
#    'url': 'https://api.hh.ru/employers/5756305',
#    'alternate_url': 'https://hh.ru/employer/5756305',
#    'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/896031.png',
#     '90': 'https://hhcdn.ru/employer-logo/4024811.png',
#     '240': 'https://hhcdn.ru/employer-logo/4024812.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=5756305',
#    'trusted': True},
#   'snippet': {'requirement': 'Отличные знания Excel, Word, Банк-клиент. Профильное образование (средне-специальное или высшее). Личные качества: самоорганизованность, внимательность, исполнительность, структурное мышление. ',
#    'responsibility': 'Работа с первичной документацией, отражение первичных документов от поставщиков (услуги и материалы), контроль дебиторской и кредиторской задолженности, взаимодействие (документооборот) с...'},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '48809147',
#   'premium': False,
#   'name': 'Бухгалтер по расчету заработной платы',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '58', 'name': 'Липецк', 'url': 'https://api.hh.ru/areas/58'},
#   'salary': {'from': 40000, 'to': None, 'currency': 'RUR', 'gross': True},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Липецк',
#    'street': 'Передельческая улица',
#    'building': '3',
#    'description': None,
#    'lat': 52.571005,
#    'lng': 39.674777,
#    'raw': 'Липецк, Передельческая улица, 3',
#    'metro': None,
#    'metro_stations': [],
#    'id': '915424'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2021-10-13T16:13:29+0300',
#   'created_at': '2021-10-13T16:13:29+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=48809147',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/48809147?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/48809147',
#   'relations': [],
#   'employer': {'id': '785093',
#    'name': 'ЛАСАР',
#    'url': 'https://api.hh.ru/employers/785093',
#    'alternate_url': 'https://hh.ru/employer/785093',
#    'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/900460.jpg',
#     '90': 'https://hhcdn.ru/employer-logo/4042527.jpeg',
#     '240': 'https://hhcdn.ru/employer-logo/4042528.jpeg'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=785093',
#    'trusted': True},
#   'snippet': {'requirement': 'Высшее образование. - Опыт работы (расчет з.п., ведение участка "Банк"). - Знание программы 1С.',
#    'responsibility': 'Расчет и начисление заработной платы (численность до 100 чел.): премии, доплаты, надбавки, удержания, сверхурочные часы, пособия и т.д.. '},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '48876299',
#   'premium': False,
#   'name': 'Бухгалтер',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1002',
#    'name': 'Минск',
#    'url': 'https://api.hh.ru/areas/1002'},
#   'salary': {'from': 1040, 'to': 1040, 'currency': 'BYR', 'gross': False},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Минск',
#    'street': 'улица Платонова',
#    'building': '34',
#    'description': None,
#    'lat': 53.91216,
#    'lng': 27.599174,
#    'raw': 'Минск, улица Платонова, 34',
#    'metro': None,
#    'metro_stations': [],
#    'id': '366704'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2021-10-15T13:56:34+0300',
#   'created_at': '2021-10-15T13:56:34+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=48876299',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/48876299?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/48876299',
#   'relations': [],
#   'employer': {'id': '233323',
#    'name': 'Сеть магазинов Мила (ГК, Парфюмбытхим)',
#    'url': 'https://api.hh.ru/employers/233323',
#    'alternate_url': 'https://hh.ru/employer/233323',
#    'logo_urls': {'90': 'https://hhcdn.ru/employer-logo/3404109.png',
#     '240': 'https://hhcdn.ru/employer-logo/3404110.png',
#     'original': 'https://hhcdn.ru/employer-logo-original/740787.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=233323',
#    'trusted': True},
#   'snippet': {'requirement': 'Высшее/среднее специальное образование. Знание бухгалтерского учета, умение работать с первичными документами. Приветствуется опыт работы в розничной сети. ',
#    'responsibility': 'Учет основных средств: поступление, перемещение, выбытие. Учет материалов в эксплуатации: поступление, передача в эксплуатацию, списание. Проведение доп. расходов по приобретению...'},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '48693128',
#   'premium': False,
#   'name': 'Бухгалтер на участок',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': {'from': 70000, 'to': 70000, 'currency': 'RUR', 'gross': False},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Москва',
#    'street': 'улица Горбунова',
#    'building': '2с3',
#    'description': None,
#    'lat': 55.726315,
#    'lng': 37.399399,
#    'raw': 'Москва, улица Горбунова, 2с3',
#    'metro': None,
#    'metro_stations': [],
#    'id': '5321756'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2021-10-14T09:26:09+0300',
#   'created_at': '2021-10-14T09:26:09+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=48693128',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/48693128?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/48693128',
#   'relations': [],
#   'employer': {'id': '1863360',
#    'name': 'Ямское поле',
#    'url': 'https://api.hh.ru/employers/1863360',
#    'alternate_url': 'https://hh.ru/employer/1863360',
#    'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/515005.png',
#     '90': 'https://hhcdn.ru/employer-logo/2501608.png',
#     '240': 'https://hhcdn.ru/employer-logo/2501609.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=1863360',
#    'trusted': True},
#   'snippet': {'requirement': 'Опыт работы в 1С <highlighttext>Бухгалтерия</highlighttext>, 1С Управление торговлей. Знание банковских систем. Знание бухгалтерских проводок. Внимательность, пунктуальность.',
#    'responsibility': 'Получение и обработка выписок банка и их отражение на счетах бух. учета (60,62,76,66,67,55). '},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '48569189',
#   'premium': False,
#   'name': 'Главный бухгалтер',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '26', 'name': 'Воронеж', 'url': 'https://api.hh.ru/areas/26'},
#   'salary': {'from': 100000, 'to': 120000, 'currency': 'RUR', 'gross': False},
# ...
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': {'from': 80000, 'to': None, 'currency': 'RUR', 'gross': False},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Москва',
#    'street': 'улица Василия Петушкова',
#    'building': '7',
#    'description': None,
#    'lat': 55.837454,
#    'lng': 37.405606,
#    'raw': 'Москва, улица Василия Петушкова, 7',
#    'metro': None,
#    'metro_stations': [],
#    'id': '5279960'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2021-10-13T11:19:59+0300',
#   'created_at': '2021-10-13T11:19:59+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=48164561',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/48164561?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/48164561',
#   'relations': [],
#   'employer': {'id': '75974',
#    'name': 'Техноавиа',
#    'url': 'https://api.hh.ru/employers/75974',
#    'alternate_url': 'https://hh.ru/employer/75974',
#    'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/1724415.png',
#     'original': 'https://hhcdn.ru/employer-logo-original/320512.png',
#     '90': 'https://hhcdn.ru/employer-logo/1724414.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=75974',
#    'trusted': True},
#   'snippet': {'requirement': 'Профильное образование. Знание программы «1С: Предприятие 8.3 обязательно. Уверенный пользователь ПК, MicrosoftOutlook, MicrosoftExcel. Опыт работы не менее 3...',
#    'responsibility': 'Ведение участка заработная плата в полном объеме в программе 1С:Зарплата и Кадры 8.3. Начисление заработной платы, стимулирующих...'},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '48797643',
#   'premium': False,
#   'name': 'Бухгалтер',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '99', 'name': 'Уфа', 'url': 'https://api.hh.ru/areas/99'},
#   'salary': {'from': 35000, 'to': None, 'currency': 'RUR', 'gross': False},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Уфа',
#    'street': 'улица Рихарда Зорге',
#    'building': '17/4',
#    'description': None,
#    'lat': 54.753248,
#    'lng': 55.983512,
#    'raw': 'Уфа, улица Рихарда Зорге, 17/4',
#    'metro': None,
#    'metro_stations': [],
#    'id': '3180114'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2021-10-13T12:47:16+0300',
#   'created_at': '2021-10-13T12:47:16+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=48797643',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/48797643?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/48797643',
#   'relations': [],
#   'employer': {'id': '3942659',
#    'name': 'ИндиФуд',
#    'url': 'https://api.hh.ru/employers/3942659',
#    'alternate_url': 'https://hh.ru/employer/3942659',
#    'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3552860.png',
#     '90': 'https://hhcdn.ru/employer-logo/3552859.png',
#     'original': 'https://hhcdn.ru/employer-logo-original/777992.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3942659',
#    'trusted': True},
#   'snippet': {'requirement': 'Знание 1С УТ, 1С <highlighttext>Бухгалтерия</highlighttext> 8.3. Коммуникабельность, внимательность, ответственность. Опыт работы в торговых сетях приветствуется!',
#    'responsibility': 'Проверка и проведение первичной документации. Контроль, разнесение счетов бухгалтерского и аналитического учета. Формирование актов взаиморасчета с контрагентами,сверка. '},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '48868668',
#   'premium': False,
#   'name': 'Бухгалтер',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '212',
#    'name': 'Тольятти',
#    'url': 'https://api.hh.ru/areas/212'},
#   'salary': {'from': 30000, 'to': None, 'currency': 'RUR', 'gross': False},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Тольятти',
#    'street': 'Обводное шоссе',
#    'building': '50',
#    'description': None,
#    'lat': 53.57801,
#    'lng': 49.400567,
#    'raw': 'Тольятти, Обводное шоссе, 50',
#    'metro': None,
#    'metro_stations': [],
#    'id': '3981822'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2021-10-15T11:11:10+0300',
#   'created_at': '2021-10-15T11:11:10+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=48868668',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/48868668?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/48868668',
#   'relations': [],
#   'employer': {'id': '62838',
#    'name': 'ТАИФ-НК АЗС',
#    'url': 'https://api.hh.ru/employers/62838',
#    'alternate_url': 'https://hh.ru/employer/62838',
#    'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3128325.png',
#     '90': 'https://hhcdn.ru/employer-logo/3128324.png',
#     'original': 'https://hhcdn.ru/employer-logo-original/671798.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=62838',
#    'trusted': True},
#   'snippet': {'requirement': 'Высшее образование. Уверенное пользование 1С:УПП, Microsoft office, Directum, Консультант Плюс. Внимательность, ответственность, пунктуальность.',
#    'responsibility': 'Ведение бухгалтерского и налогового учета в части движения сопутствующих товаров на АЗС( хранение, перемещение, реализация, списание). Взаиморасчеты с контрагентами ( поступление...'},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '48585366',
#   'premium': False,
#   'name': 'Бухгалтер',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': {'from': 60000, 'to': 80000, 'currency': 'RUR', 'gross': True},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Москва',
#    'street': 'Тверская улица',
#    'building': '22В',
#    'description': None,
#    'lat': 55.767235,
#    'lng': 37.602094,
#    'raw': 'Москва, Тверская улица, 22В',
#    'metro': None,
#    'metro_stations': [],
#    'id': '5973682'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2021-10-12T18:42:42+0300',
#   'created_at': '2021-10-12T18:42:42+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=48585366',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/48585366?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/48585366',
#   'relations': [],
#   'employer': {'id': '5436940',
#    'name': 'Кэмикал Синтез Трейд',
#    'url': 'https://api.hh.ru/employers/5436940',
#    'alternate_url': 'https://hh.ru/employer/5436940',
#    'logo_urls': None,
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=5436940',
#    'trusted': True},
#   'snippet': {'requirement': 'Образование: высшее профильное. Знание ВЭД обязательно. Знание 1С обязательно. Опыт работы <highlighttext>бухгалтером</highlighttext> от 3-х лет. Профессиональный стаж.',
#    'responsibility': '4. Контроль за оригиналами первичных документов. 5. Зарплатный блок. 6. Возмещение НДС из бюджета. 7. Помощь главному <highlighttext>бухгалтеру</highlighttext>.'},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '48877507',
#   'premium': False,
#   'name': 'Бухгалтер',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1512',
#    'name': 'Волжский (Волгоградская область)',
#    'url': 'https://api.hh.ru/areas/1512'},
#   'salary': {'from': None, 'to': 31200, 'currency': 'RUR', 'gross': True},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Волжский',
#    'street': 'улица 6-я Автодорога',
#    'building': '18',
#    'description': None,
#    'lat': 48.811586,
#    'lng': 44.765081,
#    'raw': 'Волжский, улица 6-я Автодорога, 18',
#    'metro': None,
#    'metro_stations': [],
#    'id': '808484'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2021-10-15T14:19:15+0300',
#   'created_at': '2021-10-15T14:19:15+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=48877507',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/48877507?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/48877507',
#   'relations': [],
#   'employer': {'id': '605114',
#    'name': 'Волжский абразивный завод',
#    'url': 'https://api.hh.ru/employers/605114',
#    'alternate_url': 'https://hh.ru/employer/605114',
#    'logo_urls': {'90': 'https://hhcdn.ru/employer-logo/372637.png',
#     'original': 'https://hhcdn.ru/employer-logo-original/166224.bmp',
#     '240': 'https://hhcdn.ru/employer-logo/445494.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=605114',
#    'trusted': True},
#   'snippet': {'requirement': 'Среднее профессиональное (бухгалтерское или экономическое) образование. Опыт работы не менее 3-х лет. Навыки ведения бухгалтерского учета с помощью специализированного...',
#    'responsibility': 'Осуществлять прием, контроль и обработку первичной документации по выпуску, внутреннему перемещению, списанию готовой продукции. Осуществлять прием и контроль первичной документации...'},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '48328177',
#   'premium': False,
#   'name': 'Бухгалтер',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': {'from': None, 'to': 70000, 'currency': 'RUR', 'gross': True},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Москва',
#    'street': 'Серпуховско-Тимирязевская линия',
#    'building': 'метро Нагорная',
#    'description': None,
#    'lat': 55.672691,
#    'lng': 37.610592,
#    'raw': 'Москва, Серпуховско-Тимирязевская линия, метро Нагорная',
#    'metro': {'station_name': 'Нагорная',
#     'line_name': 'Серпуховско-Тимирязевская',
#     'station_id': '9.86',
#     'line_id': '9',
#     'lat': 55.672962,
#     'lng': 37.610397},
#    'metro_stations': [{'station_name': 'Нагорная',
#      'line_name': 'Серпуховско-Тимирязевская',
#      'station_id': '9.86',
#      'line_id': '9',
#      'lat': 55.672962,
#      'lng': 37.610397}],
#    'id': '6532568'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2021-10-13T12:38:16+0300',
#   'created_at': '2021-10-13T12:38:16+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=48328177',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/48328177?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/48328177',
#   'relations': [],
#   'employer': {'id': '5754024',
#    'name': 'Джанибекова Диана',
#    'url': 'https://api.hh.ru/employers/5754024',
#    'alternate_url': 'https://hh.ru/employer/5754024',
#    'logo_urls': None,
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=5754024',
#    'trusted': False},
#   'snippet': {'requirement': 'Опыт работы на аналогичном участке работы - не менее 2х лет. Хорошее знание 1С:<highlighttext>Бухгалтерия</highlighttext> 8.3, Microsoft Office...',
#    'responsibility': 'Учет расчётов с поставщиками услуг в организации на УСН. Обработка и регистрация в 1С 8.3 первичных документов поступления...'},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '48807639',
#   'premium': False,
#   'name': 'Бухгалтер',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '41',
#    'name': 'Калининград',
#    'url': 'https://api.hh.ru/areas/41'},
#   'salary': {'from': 40000, 'to': 45000, 'currency': 'RUR', 'gross': False},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Калининград',
#    'street': 'Ялтинская улица',
#    'building': '66',
#    'description': None,
#    'lat': 54.70456,
#    'lng': 20.553984,
#    'raw': 'Калининград, Ялтинская улица, 66',
#    'metro': None,
#    'metro_stations': [],
#    'id': '6631452'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2021-10-13T15:42:17+0300',
#   'created_at': '2021-10-13T15:42:17+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=48807639',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/48807639?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/48807639',
#   'relations': [],
#   'employer': {'id': '3757125',
#    'name': 'Мега-Пласт-Янтарь',
#    'url': 'https://api.hh.ru/employers/3757125',
#    'alternate_url': 'https://hh.ru/employer/3757125',
#    'logo_urls': None,
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3757125',
#    'trusted': True},
#   'snippet': {'requirement': '1С уверенный пользователь. Умение быстро усваивать новую информацию. Обязанности: 5 лет стаж.',
#    'responsibility': 'УСН (ведение бухучета в полном объёме), патент, транспортные услуги. Производство. Валютные операции.'},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False},
#  {'id': '48699689',
#   'premium': False,
#   'name': 'Бухгалтер платежной группы',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': {'from': 60000, 'to': None, 'currency': 'RUR', 'gross': False},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Москва',
#    'street': 'Валовая улица',
#    'building': '21к125',
#    'description': None,
#    'lat': 55.730101,
#    'lng': 37.630939,
#    'raw': 'Москва, Валовая улица, 21к125',
#    'metro': None,
#    'metro_stations': [],
#    'id': '2936924'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2021-10-14T11:05:57+0300',
#   'created_at': '2021-10-14T11:05:57+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=48699689',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/48699689?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/48699689',
#   'relations': [],
#   'employer': {'id': '1631509',
#    'name': 'А-КЛУБ',
#    'url': 'https://api.hh.ru/employers/1631509',
#    'alternate_url': 'https://hh.ru/employer/1631509',
#    'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/898840.png',
#     '90': 'https://hhcdn.ru/employer-logo/4036047.png',
#     '240': 'https://hhcdn.ru/employer-logo/4036048.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=1631509',
#    'trusted': True},
#   'snippet': {'requirement': 'Знание программы 1С <highlighttext>Бухгалтерия</highlighttext> 8.3. Опыт работы в сфере туризма предпочтителен. Опытный пользователь MS Excel. Высшее образование. ',
#    'responsibility': 'Формирование реестра платежей на день, контроль их исполнения; (в среднем 200 в день). Взаимодействие с подразделениями организации по соблюдению регламентных...'},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False}]

# %%
df = pd.DataFrame(items)
df
# Out:
#           id  premium                                   name department  \
# 0   48657968    False  Главный бухгалтер в единственном лице       None
# 1   48722257    False               Бухгалтер (производство)       None
# 2   42774239    False                  Бухгалтер ТМЦ (склад)       None
# 3   48758166    False        Делопроизводитель (бухгалтерия)       None
# 4   47709417    False                              Бухгалтер       None
# ..       ...      ...                                    ...        ...
# 95  48585366    False                              Бухгалтер       None
# 96  48877507    False                              Бухгалтер       None
# 97  48328177    False                              Бухгалтер       None
# 98  48807639    False                              Бухгалтер       None
# 99  48699689    False             Бухгалтер платежной группы       None
#
#     has_test  response_letter_required  \
# 0      False                     False
# 1      False                     False
# 2       True                     False
# 3      False                     False
# 4      False                     False
# ..       ...                       ...
# 95     False                     False
# 96     False                     False
# 97     False                     False
# 98     False                     False
# 99     False                     False
#
#                                                  area  \
# 0   {'id': '1', 'name': 'Москва', 'url': 'https://...
# 1   {'id': '2', 'name': 'Санкт-Петербург', 'url': ...
# 2   {'id': '4', 'name': 'Новосибирск', 'url': 'htt...
# 3   {'id': '2', 'name': 'Санкт-Петербург', 'url': ...
# 4   {'id': '99', 'name': 'Уфа', 'url': 'https://ap...
# ..                                                ...
# 95  {'id': '1', 'name': 'Москва', 'url': 'https://...
# 96  {'id': '1512', 'name': 'Волжский (Волгоградска...
# 97  {'id': '1', 'name': 'Москва', 'url': 'https://...
# 98  {'id': '41', 'name': 'Калининград', 'url': 'ht...
# 99  {'id': '1', 'name': 'Москва', 'url': 'https://...
#
#                                                salary  \
# 0   {'from': 90000, 'to': 110000, 'currency': 'RUR...
# 1   {'from': 70000, 'to': None, 'currency': 'RUR',...
# 2   {'from': 65000, 'to': None, 'currency': 'RUR',...
# 3   {'from': 40000, 'to': None, 'currency': 'RUR',...
# 4   {'from': 40000, 'to': 40000, 'currency': 'RUR'...
# ..                                                ...
# 95  {'from': 60000, 'to': 80000, 'currency': 'RUR'...
# 96  {'from': None, 'to': 31200, 'currency': 'RUR',...
# 97  {'from': None, 'to': 70000, 'currency': 'RUR',...
# 98  {'from': 40000, 'to': 45000, 'currency': 'RUR'...
# 99  {'from': 60000, 'to': None, 'currency': 'RUR',...
#
#                                   type  \
# 0   {'id': 'open', 'name': 'Открытая'}
# 1   {'id': 'open', 'name': 'Открытая'}
# 2   {'id': 'open', 'name': 'Открытая'}
# 3   {'id': 'open', 'name': 'Открытая'}
# 4   {'id': 'open', 'name': 'Открытая'}
# ..                                 ...
# 95  {'id': 'open', 'name': 'Открытая'}
# 96  {'id': 'open', 'name': 'Открытая'}
# 97  {'id': 'open', 'name': 'Открытая'}
# 98  {'id': 'open', 'name': 'Открытая'}
# 99  {'id': 'open', 'name': 'Открытая'}
#
#                                               address  ...  \
# 0                                                None  ...
# 1   {'city': 'Санкт-Петербург', 'street': 'Лисичан...  ...
# 2                                                None  ...
# 3   {'city': 'Санкт-Петербург', 'street': 'Московс...  ...
# 4   {'city': 'Уфа', 'street': 'улица Чернышевского...  ...
# ..                                                ...  ...
# 95  {'city': 'Москва', 'street': 'Тверская улица',...  ...
# 96  {'city': 'Волжский', 'street': 'улица 6-я Авто...  ...
# 97  {'city': 'Москва', 'street': 'Серпуховско-Тими...  ...
# 98  {'city': 'Калининград', 'street': 'Ялтинская у...  ...
# 99  {'city': 'Москва', 'street': 'Валовая улица', ...  ...
#
#                      alternate_url relations  \
# 0   https://hh.ru/vacancy/48657968        []
# 1   https://hh.ru/vacancy/48722257        []
# 2   https://hh.ru/vacancy/42774239        []
# 3   https://hh.ru/vacancy/48758166        []
# 4   https://hh.ru/vacancy/47709417        []
# ..                             ...       ...
# 95  https://hh.ru/vacancy/48585366        []
# 96  https://hh.ru/vacancy/48877507        []
# 97  https://hh.ru/vacancy/48328177        []
# 98  https://hh.ru/vacancy/48807639        []
# 99  https://hh.ru/vacancy/48699689        []
#
#                                              employer  \
# 0   {'id': '11133', 'name': 'Jetcom', 'url': 'http...
# 1   {'id': '2187035', 'name': 'Nanosmoke', 'url': ...
# 2   {'id': '681883', 'name': 'Велесстрой', 'url': ...
# 3   {'id': '544626', 'name': 'NBCom Group', 'url':...
# 4   {'id': '3735399', 'name': 'Управляющая Компани...
# ..                                                ...
# 95  {'id': '5436940', 'name': 'Кэмикал Синтез Трей...
# 96  {'id': '605114', 'name': 'Волжский абразивный ...
# 97  {'id': '5754024', 'name': 'Джанибекова Диана',...
# 98  {'id': '3757125', 'name': 'Мега-Пласт-Янтарь',...
# 99  {'id': '1631509', 'name': 'А-КЛУБ', 'url': 'ht...
#
#                                               snippet  contacts  \
# 0   {'requirement': 'Опыт работы с обособленными п...      None
# 1   {'requirement': '...и 1С <highlighttext>Бухгал...      None
# 2   {'requirement': 'Опыт работы учетчиком, <highl...      None
# 3   {'requirement': 'Опыт работы на аналогичной до...      None
# 4   {'requirement': 'Знание бухгалтерского, налого...      None
# ..                                                ...       ...
# 95  {'requirement': 'Образование: высшее профильно...      None
# 96  {'requirement': 'Среднее профессиональное (бух...      None
# 97  {'requirement': 'Опыт работы на аналогичном уч...      None
# 98  {'requirement': '1С уверенный пользователь. Ум...      None
# 99  {'requirement': 'Знание программы 1С <highligh...      None
#
#                                            schedule working_days  \
# 0          {'id': 'fullDay', 'name': 'Полный день'}           []
# 1          {'id': 'fullDay', 'name': 'Полный день'}           []
# 2   {'id': 'flyInFlyOut', 'name': 'Вахтовый метод'}           []
# 3          {'id': 'fullDay', 'name': 'Полный день'}           []
# 4          {'id': 'fullDay', 'name': 'Полный день'}           []
# ..                                              ...          ...
# 95         {'id': 'fullDay', 'name': 'Полный день'}           []
# 96         {'id': 'fullDay', 'name': 'Полный день'}           []
# 97         {'id': 'fullDay', 'name': 'Полный день'}           []
# 98         {'id': 'fullDay', 'name': 'Полный день'}           []
# 99         {'id': 'fullDay', 'name': 'Полный день'}           []
#
#    working_time_intervals working_time_modes accept_temporary
# 0                      []                 []            False
# 1                      []                 []            False
# 2                      []                 []            False
# 3                      []                 []            False
# 4                      []                 []            False
# ..                    ...                ...              ...
# 95                     []                 []            False
# 96                     []                 []            False
# 97                     []                 []            False
# 98                     []                 []            False
# 99                     []                 []            False
#
# [100 rows x 28 columns]

# %%
import numpy as np

# %%
df1 = df[['id', 'name', 'area', 'salary', 'employer']]
df1
# Out:
#           id                                   name  \
# 0   48657968  Главный бухгалтер в единственном лице
# 1   48722257               Бухгалтер (производство)
# 2   42774239                  Бухгалтер ТМЦ (склад)
# 3   48758166        Делопроизводитель (бухгалтерия)
# 4   47709417                              Бухгалтер
# ..       ...                                    ...
# 95  48585366                              Бухгалтер
# 96  48877507                              Бухгалтер
# 97  48328177                              Бухгалтер
# 98  48807639                              Бухгалтер
# 99  48699689             Бухгалтер платежной группы
#
#                                                  area  \
# 0   {'id': '1', 'name': 'Москва', 'url': 'https://...
# 1   {'id': '2', 'name': 'Санкт-Петербург', 'url': ...
# 2   {'id': '4', 'name': 'Новосибирск', 'url': 'htt...
# 3   {'id': '2', 'name': 'Санкт-Петербург', 'url': ...
# 4   {'id': '99', 'name': 'Уфа', 'url': 'https://ap...
# ..                                                ...
# 95  {'id': '1', 'name': 'Москва', 'url': 'https://...
# 96  {'id': '1512', 'name': 'Волжский (Волгоградска...
# 97  {'id': '1', 'name': 'Москва', 'url': 'https://...
# 98  {'id': '41', 'name': 'Калининград', 'url': 'ht...
# 99  {'id': '1', 'name': 'Москва', 'url': 'https://...
#
#                                                salary  \
# 0   {'from': 90000, 'to': 110000, 'currency': 'RUR...
# 1   {'from': 70000, 'to': None, 'currency': 'RUR',...
# 2   {'from': 65000, 'to': None, 'currency': 'RUR',...
# 3   {'from': 40000, 'to': None, 'currency': 'RUR',...
# 4   {'from': 40000, 'to': 40000, 'currency': 'RUR'...
# ..                                                ...
# 95  {'from': 60000, 'to': 80000, 'currency': 'RUR'...
# 96  {'from': None, 'to': 31200, 'currency': 'RUR',...
# 97  {'from': None, 'to': 70000, 'currency': 'RUR',...
# 98  {'from': 40000, 'to': 45000, 'currency': 'RUR'...
# 99  {'from': 60000, 'to': None, 'currency': 'RUR',...
#
#                                              employer
# 0   {'id': '11133', 'name': 'Jetcom', 'url': 'http...
# 1   {'id': '2187035', 'name': 'Nanosmoke', 'url': ...
# 2   {'id': '681883', 'name': 'Велесстрой', 'url': ...
# 3   {'id': '544626', 'name': 'NBCom Group', 'url':...
# 4   {'id': '3735399', 'name': 'Управляющая Компани...
# ..                                                ...
# 95  {'id': '5436940', 'name': 'Кэмикал Синтез Трей...
# 96  {'id': '605114', 'name': 'Волжский абразивный ...
# 97  {'id': '5754024', 'name': 'Джанибекова Диана',...
# 98  {'id': '3757125', 'name': 'Мега-Пласт-Янтарь',...
# 99  {'id': '1631509', 'name': 'А-КЛУБ', 'url': 'ht...
#
# [100 rows x 5 columns]

# %%
df['from_'] = df['salary'].apply(lambda x: x['from'] if x is not None else None)
df
# Out:
#           id  premium                                   name department  \
# 0   48657968    False  Главный бухгалтер в единственном лице       None
# 1   48722257    False               Бухгалтер (производство)       None
# 2   42774239    False                  Бухгалтер ТМЦ (склад)       None
# 3   48758166    False        Делопроизводитель (бухгалтерия)       None
# 4   47709417    False                              Бухгалтер       None
# ..       ...      ...                                    ...        ...
# 95  48585366    False                              Бухгалтер       None
# 96  48877507    False                              Бухгалтер       None
# 97  48328177    False                              Бухгалтер       None
# 98  48807639    False                              Бухгалтер       None
# 99  48699689    False             Бухгалтер платежной группы       None
#
#     has_test  response_letter_required  \
# 0      False                     False
# 1      False                     False
# 2       True                     False
# 3      False                     False
# 4      False                     False
# ..       ...                       ...
# 95     False                     False
# 96     False                     False
# 97     False                     False
# 98     False                     False
# 99     False                     False
#
#                                                  area  \
# 0   {'id': '1', 'name': 'Москва', 'url': 'https://...
# 1   {'id': '2', 'name': 'Санкт-Петербург', 'url': ...
# 2   {'id': '4', 'name': 'Новосибирск', 'url': 'htt...
# 3   {'id': '2', 'name': 'Санкт-Петербург', 'url': ...
# 4   {'id': '99', 'name': 'Уфа', 'url': 'https://ap...
# ..                                                ...
# 95  {'id': '1', 'name': 'Москва', 'url': 'https://...
# 96  {'id': '1512', 'name': 'Волжский (Волгоградска...
# 97  {'id': '1', 'name': 'Москва', 'url': 'https://...
# 98  {'id': '41', 'name': 'Калининград', 'url': 'ht...
# 99  {'id': '1', 'name': 'Москва', 'url': 'https://...
#
#                                                salary  \
# 0   {'from': 90000, 'to': 110000, 'currency': 'RUR...
# 1   {'from': 70000, 'to': None, 'currency': 'RUR',...
# 2   {'from': 65000, 'to': None, 'currency': 'RUR',...
# 3   {'from': 40000, 'to': None, 'currency': 'RUR',...
# 4   {'from': 40000, 'to': 40000, 'currency': 'RUR'...
# ..                                                ...
# 95  {'from': 60000, 'to': 80000, 'currency': 'RUR'...
# 96  {'from': None, 'to': 31200, 'currency': 'RUR',...
# 97  {'from': None, 'to': 70000, 'currency': 'RUR',...
# 98  {'from': 40000, 'to': 45000, 'currency': 'RUR'...
# 99  {'from': 60000, 'to': None, 'currency': 'RUR',...
#
#                                   type  \
# 0   {'id': 'open', 'name': 'Открытая'}
# 1   {'id': 'open', 'name': 'Открытая'}
# 2   {'id': 'open', 'name': 'Открытая'}
# 3   {'id': 'open', 'name': 'Открытая'}
# 4   {'id': 'open', 'name': 'Открытая'}
# ..                                 ...
# 95  {'id': 'open', 'name': 'Открытая'}
# 96  {'id': 'open', 'name': 'Открытая'}
# 97  {'id': 'open', 'name': 'Открытая'}
# 98  {'id': 'open', 'name': 'Открытая'}
# 99  {'id': 'open', 'name': 'Открытая'}
#
#                                               address  ... relations  \
# 0                                                None  ...        []
# 1   {'city': 'Санкт-Петербург', 'street': 'Лисичан...  ...        []
# 2                                                None  ...        []
# 3   {'city': 'Санкт-Петербург', 'street': 'Московс...  ...        []
# 4   {'city': 'Уфа', 'street': 'улица Чернышевского...  ...        []
# ..                                                ...  ...       ...
# 95  {'city': 'Москва', 'street': 'Тверская улица',...  ...        []
# 96  {'city': 'Волжский', 'street': 'улица 6-я Авто...  ...        []
# 97  {'city': 'Москва', 'street': 'Серпуховско-Тими...  ...        []
# 98  {'city': 'Калининград', 'street': 'Ялтинская у...  ...        []
# 99  {'city': 'Москва', 'street': 'Валовая улица', ...  ...        []
#
#                                              employer  \
# 0   {'id': '11133', 'name': 'Jetcom', 'url': 'http...
# 1   {'id': '2187035', 'name': 'Nanosmoke', 'url': ...
# 2   {'id': '681883', 'name': 'Велесстрой', 'url': ...
# 3   {'id': '544626', 'name': 'NBCom Group', 'url':...
# 4   {'id': '3735399', 'name': 'Управляющая Компани...
# ..                                                ...
# 95  {'id': '5436940', 'name': 'Кэмикал Синтез Трей...
# 96  {'id': '605114', 'name': 'Волжский абразивный ...
# 97  {'id': '5754024', 'name': 'Джанибекова Диана',...
# 98  {'id': '3757125', 'name': 'Мега-Пласт-Янтарь',...
# 99  {'id': '1631509', 'name': 'А-КЛУБ', 'url': 'ht...
#
#                                               snippet contacts  \
# 0   {'requirement': 'Опыт работы с обособленными п...     None
# 1   {'requirement': '...и 1С <highlighttext>Бухгал...     None
# 2   {'requirement': 'Опыт работы учетчиком, <highl...     None
# 3   {'requirement': 'Опыт работы на аналогичной до...     None
# 4   {'requirement': 'Знание бухгалтерского, налого...     None
# ..                                                ...      ...
# 95  {'requirement': 'Образование: высшее профильно...     None
# 96  {'requirement': 'Среднее профессиональное (бух...     None
# 97  {'requirement': 'Опыт работы на аналогичном уч...     None
# 98  {'requirement': '1С уверенный пользователь. Ум...     None
# 99  {'requirement': 'Знание программы 1С <highligh...     None
#
#                                            schedule working_days  \
# 0          {'id': 'fullDay', 'name': 'Полный день'}           []
# 1          {'id': 'fullDay', 'name': 'Полный день'}           []
# 2   {'id': 'flyInFlyOut', 'name': 'Вахтовый метод'}           []
# 3          {'id': 'fullDay', 'name': 'Полный день'}           []
# 4          {'id': 'fullDay', 'name': 'Полный день'}           []
# ..                                              ...          ...
# 95         {'id': 'fullDay', 'name': 'Полный день'}           []
# 96         {'id': 'fullDay', 'name': 'Полный день'}           []
# 97         {'id': 'fullDay', 'name': 'Полный день'}           []
# 98         {'id': 'fullDay', 'name': 'Полный день'}           []
# 99         {'id': 'fullDay', 'name': 'Полный день'}           []
#
#    working_time_intervals working_time_modes accept_temporary    from_
# 0                      []                 []            False  90000.0
# 1                      []                 []            False  70000.0
# 2                      []                 []            False  65000.0
# 3                      []                 []            False  40000.0
# 4                      []                 []            False  40000.0
# ..                    ...                ...              ...      ...
# 95                     []                 []            False  60000.0
# 96                     []                 []            False      NaN
# 97                     []                 []            False      NaN
# 98                     []                 []            False  40000.0
# 99                     []                 []            False  60000.0
#
# [100 rows x 29 columns]

# %%
df1['from_'] = df['salary'].apply(lambda x: x['from'] if x is not None else None)
df1
# Out:
# <ipython-input-25-b5dde938579b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['from_'] = df['salary'].apply(lambda x: x['from'] if x is not None else None)
#           id                                   name  \
# 0   48657968  Главный бухгалтер в единственном лице
# 1   48722257               Бухгалтер (производство)
# 2   42774239                  Бухгалтер ТМЦ (склад)
# 3   48758166        Делопроизводитель (бухгалтерия)
# 4   47709417                              Бухгалтер
# ..       ...                                    ...
# 95  48585366                              Бухгалтер
# 96  48877507                              Бухгалтер
# 97  48328177                              Бухгалтер
# 98  48807639                              Бухгалтер
# 99  48699689             Бухгалтер платежной группы
#
#                                                  area  \
# 0   {'id': '1', 'name': 'Москва', 'url': 'https://...
# 1   {'id': '2', 'name': 'Санкт-Петербург', 'url': ...
# 2   {'id': '4', 'name': 'Новосибирск', 'url': 'htt...
# 3   {'id': '2', 'name': 'Санкт-Петербург', 'url': ...
# 4   {'id': '99', 'name': 'Уфа', 'url': 'https://ap...
# ..                                                ...
# 95  {'id': '1', 'name': 'Москва', 'url': 'https://...
# 96  {'id': '1512', 'name': 'Волжский (Волгоградска...
# 97  {'id': '1', 'name': 'Москва', 'url': 'https://...
# 98  {'id': '41', 'name': 'Калининград', 'url': 'ht...
# 99  {'id': '1', 'name': 'Москва', 'url': 'https://...
#
#                                                salary  \
# 0   {'from': 90000, 'to': 110000, 'currency': 'RUR...
# 1   {'from': 70000, 'to': None, 'currency': 'RUR',...
# 2   {'from': 65000, 'to': None, 'currency': 'RUR',...
# 3   {'from': 40000, 'to': None, 'currency': 'RUR',...
# 4   {'from': 40000, 'to': 40000, 'currency': 'RUR'...
# ..                                                ...
# 95  {'from': 60000, 'to': 80000, 'currency': 'RUR'...
# 96  {'from': None, 'to': 31200, 'currency': 'RUR',...
# 97  {'from': None, 'to': 70000, 'currency': 'RUR',...
# 98  {'from': 40000, 'to': 45000, 'currency': 'RUR'...
# 99  {'from': 60000, 'to': None, 'currency': 'RUR',...
#
#                                              employer    from_
# 0   {'id': '11133', 'name': 'Jetcom', 'url': 'http...  90000.0
# 1   {'id': '2187035', 'name': 'Nanosmoke', 'url': ...  70000.0
# 2   {'id': '681883', 'name': 'Велесстрой', 'url': ...  65000.0
# 3   {'id': '544626', 'name': 'NBCom Group', 'url':...  40000.0
# 4   {'id': '3735399', 'name': 'Управляющая Компани...  40000.0
# ..                                                ...      ...
# 95  {'id': '5436940', 'name': 'Кэмикал Синтез Трей...  60000.0
# 96  {'id': '605114', 'name': 'Волжский абразивный ...      NaN
# 97  {'id': '5754024', 'name': 'Джанибекова Диана',...      NaN
# 98  {'id': '3757125', 'name': 'Мега-Пласт-Янтарь',...  40000.0
# 99  {'id': '1631509', 'name': 'А-КЛУБ', 'url': 'ht...  60000.0
#
# [100 rows x 6 columns]

# %%
df1['to_'] = df['salary'].apply(lambda x: x['to'] if x is not None else None)
df1
# Out:
# <ipython-input-26-5c29f0d34cc6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['to_'] = df['salary'].apply(lambda x: x['to'] if x is not None else None)
#           id                                   name  \
# 0   48657968  Главный бухгалтер в единственном лице
# 1   48722257               Бухгалтер (производство)
# 2   42774239                  Бухгалтер ТМЦ (склад)
# 3   48758166        Делопроизводитель (бухгалтерия)
# 4   47709417                              Бухгалтер
# ..       ...                                    ...
# 95  48585366                              Бухгалтер
# 96  48877507                              Бухгалтер
# 97  48328177                              Бухгалтер
# 98  48807639                              Бухгалтер
# 99  48699689             Бухгалтер платежной группы
#
#                                                  area  \
# 0   {'id': '1', 'name': 'Москва', 'url': 'https://...
# 1   {'id': '2', 'name': 'Санкт-Петербург', 'url': ...
# 2   {'id': '4', 'name': 'Новосибирск', 'url': 'htt...
# 3   {'id': '2', 'name': 'Санкт-Петербург', 'url': ...
# 4   {'id': '99', 'name': 'Уфа', 'url': 'https://ap...
# ..                                                ...
# 95  {'id': '1', 'name': 'Москва', 'url': 'https://...
# 96  {'id': '1512', 'name': 'Волжский (Волгоградска...
# 97  {'id': '1', 'name': 'Москва', 'url': 'https://...
# 98  {'id': '41', 'name': 'Калининград', 'url': 'ht...
# 99  {'id': '1', 'name': 'Москва', 'url': 'https://...
#
#                                                salary  \
# 0   {'from': 90000, 'to': 110000, 'currency': 'RUR...
# 1   {'from': 70000, 'to': None, 'currency': 'RUR',...
# 2   {'from': 65000, 'to': None, 'currency': 'RUR',...
# 3   {'from': 40000, 'to': None, 'currency': 'RUR',...
# 4   {'from': 40000, 'to': 40000, 'currency': 'RUR'...
# ..                                                ...
# 95  {'from': 60000, 'to': 80000, 'currency': 'RUR'...
# 96  {'from': None, 'to': 31200, 'currency': 'RUR',...
# 97  {'from': None, 'to': 70000, 'currency': 'RUR',...
# 98  {'from': 40000, 'to': 45000, 'currency': 'RUR'...
# 99  {'from': 60000, 'to': None, 'currency': 'RUR',...
#
#                                              employer    from_       to_
# 0   {'id': '11133', 'name': 'Jetcom', 'url': 'http...  90000.0  110000.0
# 1   {'id': '2187035', 'name': 'Nanosmoke', 'url': ...  70000.0       NaN
# 2   {'id': '681883', 'name': 'Велесстрой', 'url': ...  65000.0       NaN
# 3   {'id': '544626', 'name': 'NBCom Group', 'url':...  40000.0       NaN
# 4   {'id': '3735399', 'name': 'Управляющая Компани...  40000.0   40000.0
# ..                                                ...      ...       ...
# 95  {'id': '5436940', 'name': 'Кэмикал Синтез Трей...  60000.0   80000.0
# 96  {'id': '605114', 'name': 'Волжский абразивный ...      NaN   31200.0
# 97  {'id': '5754024', 'name': 'Джанибекова Диана',...      NaN   70000.0
# 98  {'id': '3757125', 'name': 'Мега-Пласт-Янтарь',...  40000.0   45000.0
# 99  {'id': '1631509', 'name': 'А-КЛУБ', 'url': 'ht...  60000.0       NaN
#
# [100 rows x 7 columns]

# %%
df1[['id', 'name', 'from_', 'to_']] # Вакансии
# Out:
#           id                                   name    from_       to_
# 0   48657968  Главный бухгалтер в единственном лице  90000.0  110000.0
# 1   48722257               Бухгалтер (производство)  70000.0       NaN
# 2   42774239                  Бухгалтер ТМЦ (склад)  65000.0       NaN
# 3   48758166        Делопроизводитель (бухгалтерия)  40000.0       NaN
# 4   47709417                              Бухгалтер  40000.0   40000.0
# ..       ...                                    ...      ...       ...
# 95  48585366                              Бухгалтер  60000.0   80000.0
# 96  48877507                              Бухгалтер      NaN   31200.0
# 97  48328177                              Бухгалтер      NaN   70000.0
# 98  48807639                              Бухгалтер  40000.0   45000.0
# 99  48699689             Бухгалтер платежной группы  60000.0       NaN
#
# [100 rows x 4 columns]

# %%
df1[['from_', 'to_']].apply(lambda x: x)
# Out:
#       from_       to_
# 0   90000.0  110000.0
# 1   70000.0       NaN
# 2   65000.0       NaN
# 3   40000.0       NaN
# 4   40000.0   40000.0
# ..      ...       ...
# 95  60000.0   80000.0
# 96      NaN   31200.0
# 97      NaN   70000.0
# 98  40000.0   45000.0
# 99  60000.0       NaN
#
# [100 rows x 2 columns]

# %%
df2 = pd.DataFrame(df1['employer'].apply(lambda x: x['id'])).rename(columns={'employer': 'id'})
df2
# Out:
#          id
# 0     11133
# 1   2187035
# 2    681883
# 3    544626
# 4   3735399
# ..      ...
# 95  5436940
# 96   605114
# 97  5754024
# 98  3757125
# 99  1631509
#
# [100 rows x 1 columns]

# %%
df2['name'] = df1['employer'].apply(lambda x: x['name'])
df2
# Out:
#          id                             name
# 0     11133                           Jetcom
# 1   2187035                        Nanosmoke
# 2    681883                       Велесстрой
# 3    544626                      NBCom Group
# 4   3735399  Управляющая Компания РЕМ-Сервис
# ..      ...                              ...
# 95  5436940             Кэмикал Синтез Трейд
# 96   605114        Волжский абразивный завод
# 97  5754024                Джанибекова Диана
# 98  3757125                Мега-Пласт-Янтарь
# 99  1631509                           А-КЛУБ
#
# [100 rows x 2 columns]

# %%
df1['area'].apply(lambda x: x['id'])
# Out:
# 0        1
# 1        2
# 2        4
# 3        2
# 4       99
#       ...
# 95       1
# 96    1512
# 97       1
# 98      41
# 99       1
# Name: area, Length: 100, dtype: object

# %%
df1['area'].apply(lambda x: x['name'])
# Out:
# 0                               Москва
# 1                      Санкт-Петербург
# 2                          Новосибирск
# 3                      Санкт-Петербург
# 4                                  Уфа
#                     ...
# 95                              Москва
# 96    Волжский (Волгоградская область)
# 97                              Москва
# 98                         Калининград
# 99                              Москва
# Name: area, Length: 100, dtype: object

# %%
df1['area']
# Out:
# 0     {'id': '1', 'name': 'Москва', 'url': 'https://...
# 1     {'id': '2', 'name': 'Санкт-Петербург', 'url': ...
# 2     {'id': '4', 'name': 'Новосибирск', 'url': 'htt...
# 3     {'id': '2', 'name': 'Санкт-Петербург', 'url': ...
# 4     {'id': '99', 'name': 'Уфа', 'url': 'https://ap...
#                             ...
# 95    {'id': '1', 'name': 'Москва', 'url': 'https://...
# 96    {'id': '1512', 'name': 'Волжский (Волгоградска...
# 97    {'id': '1', 'name': 'Москва', 'url': 'https://...
# 98    {'id': '41', 'name': 'Калининград', 'url': 'ht...
# 99    {'id': '1', 'name': 'Москва', 'url': 'https://...
# Name: area, Length: 100, dtype: object

# %%
def find_parent_id(x):
    last_name = None
    x = requests.get(x['url']).json()
    return x['parent_id']

# %%
find_parent_id(df1.area[0])
# Out:
# '113'

# %%
df3 = pd.DataFrame(df1['area'].apply(lambda x: x['id'])).rename(columns={'area': 'id'})
df3
# Out:
#       id
# 0      1
# 1      2
# 2      4
# 3      2
# 4     99
# ..   ...
# 95     1
# 96  1512
# 97     1
# 98    41
# 99     1
#
# [100 rows x 1 columns]

# %%
df3['name'] = df1['area'].apply(lambda x: x['name'])
df3
# Out:
#       id                              name
# 0      1                            Москва
# 1      2                   Санкт-Петербург
# 2      4                       Новосибирск
# 3      2                   Санкт-Петербург
# 4     99                               Уфа
# ..   ...                               ...
# 95     1                            Москва
# 96  1512  Волжский (Волгоградская область)
# 97     1                            Москва
# 98    41                       Калининград
# 99     1                            Москва
#
# [100 rows x 2 columns]

# %%
df3['parent_id'] = df1['area'].apply(find_parent_id)

# %%
df3
# Out:
#       id                              name parent_id
# 0      1                            Москва       113
# 1      2                   Санкт-Петербург       113
# 2      4                       Новосибирск      1202
# 3      2                   Санкт-Петербург       113
# 4     99                               Уфа      1347
# ..   ...                               ...       ...
# 95     1                            Москва       113
# 96  1512  Волжский (Волгоградская область)      1511
# 97     1                            Москва       113
# 98    41                       Калининград      1020
# 99     1                            Москва       113
#
# [100 rows x 3 columns]

# %%
requests.get(df1.area[0]['url']).json()
# Out:
# {'id': '1', 'parent_id': '113', 'name': 'Москва', 'areas': []}

# %%
df1.area[0]
# Out:
# {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'}

# %%
df1.area[0]
# Out:
# {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'}

# %%
df1.head(1)
# Out:
#          id                                   name  \
# 0  48657968  Главный бухгалтер в единственном лице
#
#                                                 area  \
# 0  {'id': '1', 'name': 'Москва', 'url': 'https://...
#
#                                               salary  \
# 0  {'from': 90000, 'to': 110000, 'currency': 'RUR...
#
#                                             employer    from_       to_
# 0  {'id': '11133', 'name': 'Jetcom', 'url': 'http...  90000.0  110000.0

# %%
df1.values[0]
# Out:
# array(['48657968', 'Главный бухгалтер в единственном лице',
#        {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#        {'from': 90000, 'to': 110000, 'currency': 'RUR', 'gross': False},
#        {'id': '11133', 'name': 'Jetcom', 'url': 'https://api.hh.ru/employers/11133', 'alternate_url': 'https://hh.ru/employer/11133', 'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/516428.png', '90': 'https://hhcdn.ru/employer-logo/2507288.png', '240': 'https://hhcdn.ru/employer-logo/2507289.png'}, 'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=11133', 'trusted': True},
#        90000.0, 110000.0], dtype=object)

# %%
str(df3.values[0].tolist())
# Out:
# "['1', 'Москва', '113']"

# %%
#Безрезультатно
from_ = [x for x in np.where(str(df1['from_']) == 'nan', df1['to_'], df1['from_'])]
to_ = [x for x in np.where(str(df1['to_']) == 'nan', df1['from_'], df1['to_'])]

# %%
# from_ = [for x in df1]
df1['from_'].apply(lambda x: x if str(x) != 'nan' else None)
# Out:
# 0     90000.0
# 1     70000.0
# 2     65000.0
# 3     40000.0
# 4     40000.0
#        ...
# 95    60000.0
# 96        NaN
# 97        NaN
# 98    40000.0
# 99    60000.0
# Name: from_, Length: 100, dtype: float64

# %%
from_
# Out:
# [90000.0,
#  70000.0,
#  65000.0,
#  40000.0,
#  40000.0,
#  25000.0,
#  40000.0,
#  71600.0,
#  70000.0,
#  50000.0,
#  50000.0,
#  65000.0,
#  70000.0,
#  nan,
#  60000.0,
#  100000.0,
#  60000.0,
#  60000.0,
#  40000.0,
#  40000.0,
#  1040.0,
#  70000.0,
#  100000.0,
#  60000.0,
#  34500.0,
#  70000.0,
#  40000.0,
#  45000.0,
#  75000.0,
#  60000.0,
#  60000.0,
#  65000.0,
#  60000.0,
#  nan,
#  35000.0,
#  60000.0,
#  33000.0,
#  30000.0,
#  57420.0,
#  65000.0,
#  40000.0,
#  25000.0,
#  40000.0,
#  980.0,
#  45000.0,
#  40000.0,
#  50000.0,
#  60000.0,
#  103448.0,
#  nan,
#  nan,
#  nan,
#  45000.0,
#  50000.0,
#  80000.0,
#  nan,
#  60000.0,
#  nan,
#  45000.0,
#  60000.0,
#  nan,
#  1100.0,
#  60000.0,
#  80000.0,
#  55000.0,
#  60000.0,
#  70000.0,
#  40000.0,
#  nan,
#  nan,
#  30000.0,
#  70000.0,
#  100000.0,
#  nan,
#  15000.0,
#  35000.0,
#  70000.0,
#  38000.0,
#  40000.0,
#  55000.0,
#  250000.0,
#  nan,
#  35000.0,
#  50000.0,
#  40000.0,
#  49000.0,
#  54600.0,
#  120000.0,
#  250000.0,
#  25000.0,
#  200000.0,
#  30000.0,
#  80000.0,
#  35000.0,
#  30000.0,
#  60000.0,
#  nan,
#  nan,
#  40000.0,
#  60000.0]

# %%
type(df1.loc[1]['to_'])
# Out:
# numpy.float64

# %%
np.float64('nan')
# Out:
# nan

# %%
to_
# Out:
# [110000.0,
#  nan,
#  nan,
#  nan,
#  40000.0,
#  40000.0,
#  45000.0,
#  71600.0,
#  80000.0,
#  nan,
#  nan,
#  65000.0,
#  nan,
#  90000.0,
#  nan,
#  100000.0,
#  80000.0,
#  70000.0,
#  50000.0,
#  nan,
#  1040.0,
#  70000.0,
#  120000.0,
#  60000.0,
#  nan,
#  nan,
#  nan,
#  60000.0,
#  80000.0,
#  nan,
#  65000.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  60000.0,
#  nan,
#  nan,
#  57420.0,
#  nan,
#  nan,
#  nan,
#  45000.0,
#  nan,
#  50000.0,
#  41000.0,
#  nan,
#  nan,
#  103448.0,
#  nan,
#  70000.0,
#  nan,
#  50000.0,
#  nan,
#  100000.0,
#  nan,
#  60000.0,
#  47100.0,
#  65000.0,
#  60000.0,
#  60000.0,
#  nan,
#  nan,
#  96000.0,
#  55000.0,
#  65000.0,
#  80000.0,
#  nan,
#  nan,
#  250000.0,
#  nan,
#  nan,
#  nan,
#  75000.0,
#  35000.0,
#  35000.0,
#  74000.0,
#  50000.0,
#  nan,
#  60000.0,
#  300000.0,
#  nan,
#  nan,
#  60000.0,
#  nan,
#  60000.0,
#  54600.0,
#  150000.0,
#  300000.0,
#  nan,
#  nan,
#  30000.0,
#  nan,
#  nan,
#  nan,
#  80000.0,
#  31200.0,
#  70000.0,
#  45000.0,
#  nan]

# %%
df1[(str(df1.from_) == 'nan')]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-136-725bca533759> in <module>
# ----> 1 df1[(str(df1.from_) == 'nan')]
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: False

# %%
str(df1.from_[96]) == 'nan'
# Out:
# True

# %%
[np.mean([x, y]) for x, y in zip(from_, to_)]
# Out:
# [100000.0,
#  nan,
#  nan,
#  nan,
#  40000.0,
#  32500.0,
#  42500.0,
#  71600.0,
#  75000.0,
#  nan,
#  nan,
#  65000.0,
#  nan,
#  nan,
#  nan,
#  100000.0,
#  70000.0,
#  65000.0,
#  45000.0,
#  nan,
#  1040.0,
#  70000.0,
#  110000.0,
#  60000.0,
#  nan,
#  nan,
#  nan,
#  52500.0,
#  77500.0,
#  nan,
#  62500.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  60000.0,
#  nan,
#  nan,
#  57420.0,
#  nan,
#  nan,
#  nan,
#  42500.0,
#  nan,
#  47500.0,
#  40500.0,
#  nan,
#  nan,
#  103448.0,
#  nan,
#  nan,
#  nan,
#  47500.0,
#  nan,
#  90000.0,
#  nan,
#  60000.0,
#  nan,
#  55000.0,
#  60000.0,
#  nan,
#  nan,
#  nan,
#  88000.0,
#  55000.0,
#  62500.0,
#  75000.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  25000.0,
#  35000.0,
#  72000.0,
#  44000.0,
#  nan,
#  57500.0,
#  275000.0,
#  nan,
#  nan,
#  55000.0,
#  nan,
#  54500.0,
#  54600.0,
#  135000.0,
#  275000.0,
#  nan,
#  nan,
#  30000.0,
#  nan,
#  nan,
#  nan,
#  70000.0,
#  nan,
#  nan,
#  42500.0,
#  nan]

# %%
np.mean([2, None, 4])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-48c863595a32> in <module>
# ----> 1 np.mean([2, None, 4])
#
# <__array_function__ internals> in mean(*args, **kwargs)
#
# ~/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py in mean(a, axis, dtype, out, keepdims)
#    3370             return mean(axis=axis, dtype=dtype, out=out, **kwargs)
#    3371
# -> 3372     return _methods._mean(a, axis=axis, dtype=dtype,
#    3373                           out=out, **kwargs)
#    3374
#
# ~/.local/lib/python3.8/site-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims)
#     158             is_float16_result = True
#     159
# --> 160     ret = umr_sum(arr, axis, dtype, out, keepdims)
#     161     if isinstance(ret, mu.ndarray):
#     162         ret = um.true_divide(
#
# TypeError: unsupported operand type(s) for +: 'int' and 'NoneType'

# %%
#Need mean рассчитать

# %%
import sqlite3

# %%
con = sqlite3.Connection('vacancies.db')

# %%
sql1 = '''CREATE TABLE "vacancies" 
(id int, 
name text, 
salary real);'''
sql2 = '''CREATE TABLE "employers" 
(id int, 
name text);'''
sql3 = '''CREATE TABLE "regions" 
(id int, 
name text,
parent_id int);'''

# %%
con.execute(sql1)
con.execute(sql2)
con.execute(sql3)
con.commit()

# %%
pd.read_sql('select * from "vacancies"', con=con)
# Out:
# Empty DataFrame
# Columns: [id, name, salary]
# Index: []

# %%
pd.read_sql('select * from "employers"', con=con)
# Out:
# Empty DataFrame
# Columns: [id, name]
# Index: []

# %%
pd.read_sql('select * from "regions"', con=con)
# Out:
# Empty DataFrame
# Columns: [id, name, parent_id]
# Index: []

# %%
str(df3.values[0].tolist())[1:-1]
# Out:
# "'1', 'Москва', '113'"

# %%
df3.shape[0]
# Out:
# 100

# %%
for i in range(df3.shape[0]):
    values = df3.values[i]
    values[0] = int(values[0])
    values[-1] = int(values[-1])
    res = str(values.tolist())[1:-1]
#     print(res)
    sql_insert = '''INSERT INTO "regions" VALUES ({});'''.format(res)
    con.execute(sql_insert)
con.commit()

# %%
pd.read_sql('select * from "regions"', con=con)
# Out:
#       id                              name  parent_id
# 0      1                            Москва        113
# 1      2                   Санкт-Петербург        113
# 2      4                       Новосибирск       1202
# 3      2                   Санкт-Петербург        113
# 4     99                               Уфа       1347
# ..   ...                               ...        ...
# 95     1                            Москва        113
# 96  1512  Волжский (Волгоградская область)       1511
# 97     1                            Москва        113
# 98    41                       Калининград       1020
# 99     1                            Москва        113
#
# [100 rows x 3 columns]

# %%
df2[]

# %%
for i in range(df2.shape[0]):
    values = df2.values[i]
    values[0] = int(values[0])
    res = str(values.tolist())[1:-1]
#     print(res)
    sql_insert = '''INSERT INTO "employers" VALUES ({});'''.format(res)
    con.execute(sql_insert)
con.commit()

# %%
str(df2.values[i].tolist())[1:-1]
# Out:
# "'1631509', 'А-КЛУБ'"

# %%
df2.values[i]
# Out:
# array(['1631509', 'А-КЛУБ'], dtype=object)

# %%
df2
# Out:
#          id                             name
# 0     11133                           Jetcom
# 1   2187035                        Nanosmoke
# 2    681883                       Велесстрой
# 3    544626                      NBCom Group
# 4   3735399  Управляющая Компания РЕМ-Сервис
# ..      ...                              ...
# 95  5436940             Кэмикал Синтез Трейд
# 96   605114        Волжский абразивный завод
# 97  5754024                Джанибекова Диана
# 98  3757125                Мега-Пласт-Янтарь
# 99  1631509                           А-КЛУБ
#
# [100 rows x 2 columns]

# %%
pd.read_sql('select * from "employers"', con=con)
# Out:
#          id                             name
# 0     11133                           Jetcom
# 1   2187035                        Nanosmoke
# 2    681883                       Велесстрой
# 3    544626                      NBCom Group
# 4   3735399  Управляющая Компания РЕМ-Сервис
# ..      ...                              ...
# 95  5436940             Кэмикал Синтез Трейд
# 96   605114        Волжский абразивный завод
# 97  5754024                Джанибекова Диана
# 98  3757125                Мега-Пласт-Янтарь
# 99  1631509                           А-КЛУБ
#
# [100 rows x 2 columns]

# %%
for i in range(df1.shape[0]):
    values = df1[['id', 'name', 'from_', 'to_']].values[i]
    values[0] = int(values[0])
    res = str(values.tolist())[1:-1]
#     print(res)
    sql_insert = '''INSERT INTO "vacancies" VALUES ({});'''.format(res)
    con.execute(sql_insert)
con.commit()

# %%
df1[['id', 'name', 'from_', 'to_']]
# Out:
#           id                                   name    from_       to_
# 0   48657968  Главный бухгалтер в единственном лице  90000.0  110000.0
# 1   48722257               Бухгалтер (производство)  70000.0       NaN
# 2   42774239                  Бухгалтер ТМЦ (склад)  65000.0       NaN
# 3   48758166        Делопроизводитель (бухгалтерия)  40000.0       NaN
# 4   47709417                              Бухгалтер  40000.0   40000.0
# ..       ...                                    ...      ...       ...
# 95  48585366                              Бухгалтер  60000.0   80000.0
# 96  48877507                              Бухгалтер      NaN   31200.0
# 97  48328177                              Бухгалтер      NaN   70000.0
# 98  48807639                              Бухгалтер  40000.0   45000.0
# 99  48699689             Бухгалтер платежной группы  60000.0       NaN
#
# [100 rows x 4 columns]

# %%
from flask import Flask, render_template_string, request
import flask
from flask_ngrok import run_with_ngrok

# %%
app = Flask(__name__)
run_with_ngrok(app)

@app.route("/", methods=['GET', 'POST'])
def hello():
    if request.method == 'GET':
        con = sqlite3.Connection('vacancies.db')
        avrg = pd.read_sql('select * from "employers";', con=con).to_json()
        return render_template_string(avrg)
    else:
        con = sqlite3.Connection('vacancies.db')
        city = request.get_json()['city']
        avrg_by_city = pd.read_sql('''select avg(salary) from "vacancies" where area=='{}';'''.format(city), con=con).to_json()
        return avrg_by_city

if __name__=='__main__':
    app.run()
