# %%
import requests
import pandas as pd
import numpy as np
import re
from sklearn.feature_extraction.text import TfidfVectorizer #?
from sklearn.cluster import KMeans #?
from sklearn.decomposition import PCA #?
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame()

for i in range(7):
    url = 'https://api.hh.ru/vacancies?text=data+engineer&per_page=100&only_with_salary=True&page={}'.format(i)

# %%
df = pd.DataFrame()
list(df)
# Out:
# []

# %%
url = 'https://api.hh.ru/vacancies?text=data+engineer&per_page=100&only_with_salary=True&page={}'.format(1)
requests.get(url).json().keys()
# Out:
# dict_keys(['items', 'found', 'pages', 'per_page', 'page', 'clusters', 'arguments', 'alternate_url'])

# %%
requests.get(url).json()['items']
# Out:
# [{'id': '47876485',
#   'premium': False,
#   'name': 'Senior data engineer (python)',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': {'from': 4000, 'to': 6000, 'currency': 'USD', 'gross': True},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': None,
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2021-09-13T02:44:14+0300',
#   'created_at': '2021-09-13T02:44:14+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=47876485',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/47876485?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/47876485',
#   'relations': [],
#   'employer': {'id': '4329042',
#    'name': 'TeamDirector',
#    'url': 'https://api.hh.ru/employers/4329042',
# ...

# %%
import numpy as np

xarr = np.array([1.1, 1.2, 1.3, 1.4, 1.5])
yarr = np.array([2.1, 2.2, 2.3, 2.4, 2.5])
cond = np.array([True, False, True, True, False])

# %%
list(zip(xarr, yarr, cond))
# Out:
# [(1.1, 2.1, True),
#  (1.2, 2.2, False),
#  (1.3, 2.3, True),
#  (1.4, 2.4, True),
#  (1.5, 2.5, False)]

# %%
result = [(x if c else y) for x, y, c in zip(xarr, yarr, cond)]

# %%
result
# Out:
# [1.1, 2.2, 1.3, 1.4, 2.5]

# %%
np.where(cond, xarr, yarr)
# Out:
# array([1.1, 2.2, 1.3, 1.4, 2.5])

# %%
arr = np.random.randn(4, 4)
arr
# Out:
# array([[ 0.65852509, -2.46956004,  1.3464673 ,  0.19181128],
#        [ 0.82514816, -1.37310147,  2.33341543, -0.93866523],
#        [ 1.81456778,  1.2791126 , -0.1482187 ,  1.28191893],
#        [ 1.0926257 , -0.56983399, -0.33395196,  0.37758736]])

# %%
arr > 0
# Out:
# array([[ True, False,  True,  True],
#        [ True, False,  True, False],
#        [ True,  True, False,  True],
#        [ True, False, False,  True]])

# %%
np.where(arr > 0, 2, -2)
# Out:
# array([[ 2, -2,  2,  2],
#        [ 2, -2,  2, -2],
#        [ 2,  2, -2,  2],
#        [ 2, -2, -2,  2]])

# %%
np.where(arr > 0, 2, arr)
# Out:
# array([[ 2.        , -2.46956004,  2.        ,  2.        ],
#        [ 2.        , -1.37310147,  2.        , -0.93866523],
#        [ 2.        ,  2.        , -0.1482187 ,  2.        ],
#        [ 2.        , -0.56983399, -0.33395196,  2.        ]])

# %%
np.mean([3, 4])
# Out:
# 3.5

# %%
np.mean([3, 4, 5])
# Out:
# 4.0

# %%
arr = np.random.randn(2, 2)
arr
# Out:
# array([[-0.58409635, -1.13466701],
#        [-0.71757297, -0.88902096]])

# %%
arr.mean()
# Out:
# -0.8313393232865591

# %%
dict([(1, 'first'), (2, "second")])
# Out:
# {1: 'first', 2: 'second'}

# %%
import pandas as pd

# %%
a = pd.core.series.Series([4, 5, 6])
a
# Out:
# 0    4
# 1    5
# 2    6
# dtype: int64

# %%
b = pd.core.series.Series([-4, -5, -6])
a * b
# Out:
# 0   -16
# 1   -25
# 2   -36
# dtype: int64

# %%
import seaborn as sns

# %%
a = [26.2, 35.4, 43.7, 33.3, 51.3, 30]
a
# Out:
# [26.2, 35.4, 43.7, 33.3, 51.3, 30]

# %%
np.mean(a)
# Out:
# 36.65

# %%
sns.boxplot(x=a)
# Out:
# <AxesSubplot:>

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
>>> corpus = [
...     'This is the first document.',
...     'This document is the second document.',
...     'And this is the third one.',
...     'Is this the first document?',
... ]

# %%
>>> vectorizer = TfidfVectorizer()
>>> X = vectorizer.fit_transform(corpus)
>>> vectorizer.get_feature_names()
# Out:
# ['and', 'document', 'first', 'is', 'one', 'second', 'the', 'third', 'this']

# %%
df = pd.DataFrame(X.toarray(), columns=vectorizer.get_feature_names())
df
# Out:
#         and  document     first        is       one    second       the  \
# 0  0.000000  0.469791  0.580286  0.384085  0.000000  0.000000  0.384085
# 1  0.000000  0.687624  0.000000  0.281089  0.000000  0.538648  0.281089
# 2  0.511849  0.000000  0.000000  0.267104  0.511849  0.000000  0.267104
# 3  0.000000  0.469791  0.580286  0.384085  0.000000  0.000000  0.384085
#
#       third      this
# 0  0.000000  0.384085
# 1  0.000000  0.281089
# 2  0.511849  0.267104
# 3  0.000000  0.384085
